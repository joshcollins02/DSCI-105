# %% [markdown]
# # Homework 1 - Importing and Understanding your Data

# %% [markdown]
# This is an **individual** assignment. Total: 20 points. Due:**<span style="color:red">  Sunday, September 10th, 10:00 pm </span>**.

# %% [markdown]
# In this homework assignment, we will be retrieving data directly from the Internet.

# %% [markdown]
# ### Step 1. Import the necessary library.

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Retrieve the dataset from this [address](https://raw.githubusercontent.com/catalinVeghes/DSCI-105-Applied-Data-Analytics/main/datasets/Netflix_Userbase.csv) and save it into a DataFrame named `users`.

# %%
users = pd.read_csv('https://raw.githubusercontent.com/catalinVeghes/DSCI-105-Applied-Data-Analytics/main/datasets/Netflix_Userbase.csv')
users
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %% [markdown]
# ### Step 3. Observe the first 20 entries.

# %%
users.head(20)
# Out:
#     User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0         1             Basic               10  15-01-22          10-06-23
# 1         2           Premium               15  05-09-21          22-06-23
# 2         3          Standard               12  28-02-23          27-06-23
# 3         4          Standard               12  10-07-22          26-06-23
# 4         5             Basic               10  01-05-23          28-06-23
# 5         6           Premium               15  18-03-22          27-06-23
# 6         7          Standard               12  09-12-21          25-06-23
# 7         8             Basic               10  02-04-23          24-06-23
# 8         9          Standard               12  20-10-22          23-06-23
# 9        10           Premium               15  07-01-23          22-06-23
# 10       11             Basic               10  16-05-22          22-06-23
# ...

# %% [markdown]
# ### Step 4. Observe the last 10 entries

# %%
users.tail(10)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2490     2491           Premium               13  18-07-22          11-07-23
# 2491     2492             Basic               14  19-07-22          12-07-23
# 2492     2493          Standard               11  20-07-22          11-07-23
# 2493     2494           Premium               12  21-07-22          15-07-23
# 2494     2495             Basic               15  23-07-22          12-07-23
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#             Country  Age  Gender      Device Plan Duration
# 2490         France   41  Female  Smartphone       1 Month
# ...

# %% [markdown]
# ### Step 5. What is the number of users in the dataset?

# %%
len(users)
# Out:
# 2500

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(users.columns)
# Out:
# 10

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
users.columns
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
users.index
# Out:
# RangeIndex(start=0, stop=2500, step=1)

# %% [markdown]
# ### Step 9. What is the data type of each column?

# %%
users.dtypes
# Out:
# User ID               int64
# Subscription Type    object
# Monthly Revenue       int64
# Join Date            object
# Last Payment Date    object
# Country              object
# Age                   int64
# Gender               object
# Device               object
# Plan Duration        object
# dtype: object

# %% [markdown]
# ### Step 10. Print only the 'Subscription Type' column.

# %%
users['Subscription Type']
# Out:
# 0          Basic
# 1        Premium
# 2       Standard
# 3       Standard
# 4          Basic
#           ...
# 2495     Premium
# 2496       Basic
# 2497    Standard
# 2498    Standard
# 2499       Basic
# Name: Subscription Type, Length: 2500, dtype: object

# %% [markdown]
# ### Step 11. How many different countries are in this dataset?

# %%
len(users['Country'].value_counts())
# users.Country.nunique()
# Out:
# 10

# %% [markdown]
# ### Step 12. What is the most frequent device?

# %%
users.Device.value_counts().head(1)
#users.Device.describe()
# Out:
# Laptop    636
# Name: Device, dtype: int64

# %% [markdown]
# ### Step 13. Summarize/Describe the DataFrame.

# %%
users.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %% [markdown]
# ### Step 14. Summarize/Describe all the columns.

# %%
users.describe(include='all')
# Out:
#            User ID Subscription Type  Monthly Revenue Join Date  \
# count   2500.00000              2500      2500.000000      2500
# unique         NaN                 3              NaN       300
# top            NaN             Basic              NaN  05-11-22
# freq           NaN               999              NaN        33
# mean    1250.50000               NaN        12.508400       NaN
# std      721.83216               NaN         1.686851       NaN
# min        1.00000               NaN        10.000000       NaN
# 25%      625.75000               NaN        11.000000       NaN
# 50%     1250.50000               NaN        12.000000       NaN
# 75%     1875.25000               NaN        14.000000       NaN
# max     2500.00000               NaN        15.000000       NaN
#
#        Last Payment Date Country          Age  Gender  Device Plan Duration
# count               2500    2500  2500.000000    2500    2500          2500
# ...

# %% [markdown]
# ### Step 15. Summarize/Describe only the Age column.

# %%
users.Age.describe()
# Out:
# count    2500.000000
# mean       38.795600
# std         7.171778
# min        26.000000
# 25%        32.000000
# 50%        39.000000
# 75%        45.000000
# max        51.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### Step 16. Show users whose age exceeds 50 years.

# %%
users[users.Age > 50]
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 3           4          Standard               12  10-07-22          26-06-23
# 75         76             Basic               13  29-12-21          26-06-23
# 121       122             Basic               11  03-05-22          28-06-23
# 158       159          Standard               10  21-12-22          26-06-23
# 215       216           Premium               14  08-10-22          24-06-23
# ...       ...               ...              ...       ...               ...
# 2377     2378          Standard               11  22-10-22          11-07-23
# 2392     2393          Standard               12  07-11-22          11-07-23
# 2425     2426           Premium               15  23-07-22          12-07-23
# 2448     2449           Premium               10  27-10-22          09-07-23
# 2478     2479          Standard               11  16-08-22          11-07-23
#
# ...

# %% [markdown]
# ### Step 17. What is the least popular Subscription Type?

# %%
users['Subscription Type'].value_counts().tail(1)
# Out:
# Premium    733
# Name: Subscription Type, dtype: int64

# %% [markdown]
# ### Step 18. From which country does the user with a User ID of 1000 originate?

# %%
users.iloc[999]['Country']
# Out:
# 'United States'

# %% [markdown]
# ### Step 19. Rename the column from "Age" to "User Age".

# %%
users.rename(columns={'Age':'User Age'})
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %% [markdown]
# ### Step 20. Plot the Device distribution as a pie chart (kind='pie').

# %%
users.Device.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Device'>
